# %%
import requests

url = "https://instagram120.p.rapidapi.com/api/instagram/posts"

payload = {
	"username": "keke",
	"maxId": ""
}
headers = {
	"x-rapidapi-key": "657fab907amshb3aad5de5263ecdp15c3dbjsnf266f0612d4f",
	"x-rapidapi-host": "instagram120.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'result': {'edges': [{'node': {'code': 'DTcJQxNEhmP', 'pk': '3808960119611464079', 'id': '3808960119611464079_1141197', 'ad_id': None, 'boosted_status': None, 'boost_unavailable_identifier': None, 'boost_unavailable_reason': None, 'caption': {'has_translation': None, 'created_at': 1768283538, 'pk': '18086033131896165', 'text': '🫶🏾'}, 'caption_is_edited': False, 'feed_demotion_control': None, 'feed_recs_demotion_control': None, 'taken_at': 1768283536, 'inventory_source': None, 'video_versions': [{'width': 720, 'height': 1280, 'url': 'https://instagram.fmex39-1.fna.fbcdn.net/o1/v/t16/f2/m69/AQN2mj2OEut3JOkKGTQeadTdzVCRCLWQoLBEPBRyZbi5xWpRbtttcz2_5Xuy91Xkn1tV37y1BofL-R8DKD6zQuaT.mp4?strext=1&_nc_cat=107&_nc_oc=AdlQqVrKI8tbaTL5ZvD4KSAmHolsNyo405rgS5AbCtCrw_597tbBW2u5nDMzx_O63NDvAEPjHIsFNgs_9gZ6M3hC&_nc_sid=5e9851&_nc_ht=instagram.fmex39-1.fna.fbcdn.net&_nc_ohc=l6lBdy_yaAgQ7kNvwEeag0K&efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVzc2l2ZS5JTlNUQUdSQU0uQ0xJUFMuQzMuNzIwLmRhc2hfYmFzZWxpbmVfMV92MSIs
# ...

# %%
import pandas as pd
pd.DataFrame(response.json()['result']['edges']['node'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 import pandas as pd
# ----> 2 pd.DataFrame(response.json()['result']['edges']['node'])
#
# TypeError: list indices must be integers or slices, not str

# %%
response.json().keys()
# Out:
# dict_keys(['result'])

# %%
pd.json_normalize(response.json())
# Out:
#                                         result.edges  \
# 0  [{'node': {'code': 'DTcJQxNEhmP', 'pk': '38089...
#
#        result.page_info.end_cursor  result.page_info.has_next_page  \
# 0  3805842297180048064_78677028331                            True
#
#    result.page_info.has_previous_page result.page_info.start_cursor  \
# 0                               False                          None
#
#   result.version
# 0             v1

# %%
df = pd.DataFrame([e['node'] for e in response.json()['result']['edges']]).info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 83 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   code                                  12 non-null     object
#  1   pk                                    12 non-null     object
#  2   id                                    12 non-null     object
#  3   ad_id                                 0 non-null      object
#  4   boosted_status                        0 non-null      object
#  5   boost_unavailable_identifier          0 non-null      object
#  6   boost_unavailable_reason              0 non-null      object
#  7   caption                               12 non-null     object
#  8   caption_is_edited                     12 non-null     bool
#  9   feed_demotion_control                 0 non-null      object
#  10  feed_recs_demotion_control            0 non-null      object
# ...

# %%
pd.DataFrame([e['node'] for e in response.json()['result']['edges']])
# Out:
#            code                   pk                               id ad_id  \
# 0   DTcJQxNEhmP  3808960119611464079      3808960119611464079_1141197  None
# 1   DSkwZHkj_dO  3793369618501859150      3793369618501859150_1141197  None
# 2   DTwQbLjj6bb  3814621120960636635      3814621120960636635_1141197  None
# 3   DTq58-kkoHO  3813114913527857614      3813114913527857614_1141197  None
# 4   DTmCcxlETN7  3811744908089308027      3811744908089308027_1141197  None
# 5   DTgug_lgQIq  3810249862193152554      3810249862193152554_1141197  None
# 6   DTeZhKjkWqy  3809594565041679026      3809594565041679026_1141197  None
# 7   DTeMx0QEb2Q  3809538534718684560  3809538534718684560_56372226181  None
# 8   DTeAkOPEjNK  3809484823988417354      3809484823988417354_1141197  None
# 9   DTdZ2PdD5ui  3809314538433518498  3809314538433518498_53018702143  None
# 10  DTS-IrfD9eh  3806377910413023137  3806377910413023137_19846578012  None
# ...
